# %%
import numpy as np
import pytest
import os
import matplotlib.pyplot as plt
import perturbopy.postproc as ppy


sc = ppy.SpectralCumulant.from_hdf5_yaml('sto_spectral_cumulant.h5', 'sto_spectral-cum.yml')
fig, ax = plt.subplots()
sc.plot_Aw(plt, ax, ik=0,ib=0,it=0)
sc.plot_Aw(plt, ax, ik=0,ib=0,it=1)
# Out:
# <Axes: xlabel='$\\omega-\\epsilon_{nk}$ (eV)', ylabel='A($\\omega$) (eV$^{-1}$)'>
